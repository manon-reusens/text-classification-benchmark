# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from util.dataloader import DataLoader
from preprocessing import Preprocessor
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Saiga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Saiga\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
#Load data : Here all emotion datasets
dl = DataLoader(['emotion'])
data = dl.load()

# %% [markdown]
# data is a nested dictionary where keys are referring to the datasets and subkeys (if any) are referring to the available splits

# %%
#Available datasets
print(data.keys())
#Available splits for the CARER dataset
print(data['CARER'].keys())
# Out:
# dict_keys(['eval_emotion', 'CARER', 'silicone'])
# dict_keys(['train', 'val', 'test'])

# %%
#Show first rows of the eval_emotion train set
eval_emotion_train = data['eval_emotion']['train']
eval_emotion_train.head()
# Out:
#    label                                               text
# 0      2  “Worry is a down payment on a problem you may ...
# 1      0  My roommate: it's okay that we can't spell bec...
# 2      1  No but that's so cute. Atsu was probably shy a...
# 3      0  Rooneys fucking untouchable isn't he? Been fuc...
# 4      3  it's pretty depressing when u hit pan on ur fa...

# %% [markdown]
# Currently the preprocessing includes:
# - lowercasing
# - removing unicode characters, punctuation, and letters repeated more than twice
# - tokenizing (with tweet or word tokenizer depending on the data)
# - dropping digits, stopwords, emojis and urls from the tokenized sequence
# - lemmatization

# %%
#Initialize preprocessors
preprocessor = Preprocessor() #Preprocessor for standard text
tweet_preprocessor = Preprocessor(is_tweet=True) #Preprocessor for tweets

# %%
#Preprocess the text
eval_emotion_train['processed_text'] = tweet_preprocessor.preprocess(eval_emotion_train)
# Out:
# 3257 rows preprocessed in 3.1632115840911865 seconds

# %%
eval_emotion_train.head()
# Out:
#    label                                               text  \
# 0      2  “Worry is a down payment on a problem you may ...
# 1      0  My roommate: it's okay that we can't spell bec...
# 2      1  No but that's so cute. Atsu was probably shy a...
# 3      0  Rooneys fucking untouchable isn't he? Been fuc...
# 4      3  it's pretty depressing when u hit pan on ur fa...
#
#                                       processed_text
# 0  worry payment problem may never joyce meyer mo...
# 1  roommate okay cant spell autocorrect terrible ...
# 2  thats cute atsu probably shy photo cherry help...
# 3  rooneys fucking untouchable isnt fucking dread...
# 4  pretty depressing u hit pan ur favourite highl...

# %%
eval_emotion_train.processed_text.to_list()
# Out:
# ['worry payment problem may never joyce meyer motivation leadership worry',
#  'roommate okay cant spell autocorrect terrible firstworldprobs',
#  'thats cute atsu probably shy photo cherry helped uwu',
#  'rooneys fucking untouchable isnt fucking dreadful depay looked decentishtonight',
#  'pretty depressing u hit pan ur favourite highlighter',
#  'user pussy weak heard stfu bitch got threaten pregnant',
#  'making yearly transition excited hopeful college returner sick exhausted pessimist college',
#  'tiller breezy collab album rapping singing prolly fire',
#  'user broadband shocking regretting signing angry shouldofgonewithvirgin',
#  'user look teef growl',
#  'user user usa embarrassing watch last time guy game horrible joke',
#  'newyork several baloch amp indian activist hold demonstration outside user headquarters demanding pak stop exporting terror india',
#  'glee filled normy dry humping recent high profile celebrity break pathetic amp wrong world today',
#  'fucking muppet user stalker',
#  'autocorrect change em resent greatly',
#  'user would never strategically vote someone dont agree lot clinton vote based fear negativity',
#  'user hater low self worth self righteous delusion cower thought change change inevitable',
#  'saved ordering risk life didnt panic stayed calm rescued',
#  'user uggh thats really horrible youre bad person stretch imagination hope person realizes',
#  'user user user tamra would f swung tamrankelly piece needstobeadmitted bully',
#  'love happiness sadness feeling dependent another person',
#  'possible changing med best done stress difficult tell part despair circumstantial drug',
#  'im also definitely still bitter yellow ranger asian asian representation hollywood essentially shrug anyway',
#  'user irony protesting kind stuff orwellian nightmare think theyre fighting',
#  'user user nah way thats horrible',
#  'user think becz u much terror pak nd urself leader u forgot difference btw leader nd terrorist',
#  'angel delight everything',
#  'puzzle investing opening portland feodal population correlative straight snorting infuriate xlzjyhg',
#  'believe im gonna start singing snap story tractor switch little bit',
#  'rage rage ep coming soon ill keep posted youtube youtubegaming rage',
#  'started watching glee week addicted glee gleek',
#  'jorge deserves honestly he weak 90dayfiance',
#  'user shit doesnt even begin describe fiery little demon straight hell',
#  'user user ditto amazing atmosphere philiplein cheerleader stunt londonevents cheer',
#  'interview preparation hate talking one dull subject matter yawnoff',
#  'manchester derby home',
#  'itd probably useful woman im dealing rereading article woman harassed subway concern',
#  'want playful relationshipnme kick couch',
#  'romero fucking dreadful like seriously month old better',
#  'user taken granted misogyny air treated normal angry response pathological',
#  'user oh see ive seen many people mourn loss surprised see tweet suppose old sa',
#  'gutted dropped one earring sink school',
#  'happy birthday stephen king man responsible best horror past year whole bunch worst',
#  'courage always rise every attempt intimidate menelizabeth bennett pride prejudicenquotes courage faceyourfears',
#  'good day work get shake jim lehrers hand thanks user still kicking shy hug user',
#  'im bored fat full ridiculously overweight roll galore',
#  'user flirt simper pout repeat yuck',
#  'trumpism likewise rest bed racial resentment made knowingly intentionally long trump got politics',
#  'there bpharm guy eish guy brings anger life see nje like darkness fill user know',
#  'tear eye dry wont im burning like wire lightbulb',
#  'hell fury like woman scorned william congreve',
#  'user tried get earlier flt 2day user turnd away bcuz late agent let pa silvereliteleftbehind',
#  'user wish could someday come spain play cant believe im going see sad',
#  'val got little big hiking boot bakewell little terror gbbo',
#  'user bts trilogy mv time fav quite gloomy beautiful well',
#  'user user prudence suggests bump week viewed skepticism mediahrc axis angry',
#  'thank disney themed episode letting discover amazing user hilarious',
#  'need new outlet rage',
#  'rewatching raising hope hub time totally forgot hilarious herewego',
#  'user user wow heard forever random great sting xph',
#  'may optimism tomorrow foundation today',
#  'user user user nnand also trying find youtube fucking nightmare',
#  'user spent fucking hour still cant get dam siva fragment fellwinters peak mountain',
#  'happy birthday lost lost dharmainitiative 12years 22september2004 oceanic',
#  'peoplelikemebecause see happy exterior hopelessness sometimes feel inside depression anxietyprobz',
#  'people go speed limit irritate',
#  'ff nnthefamilyx nnsoul blue amp rock bandnnmusic heartnnwith soul amp passion nnxx xx',
#  'user user ohh come sense terror supporting stone pelting vandalizing ppl gather b4 protest announce',
#  'fav movie horror dont make like used havent seen great one year',
#  'id like bridge divide right left twitter say new tweet truncating thing fucking awful',
#  'user shy xd',
#  'happened need smoke',
#  'joes gf started singing star joe got angry sing right started angrily singing back',
#  'user remember heyday lady range age id say mid 30 early 70',
#  'user house get instestines scare poop ill shit pant',
#  'user user user nndo redneck intellectually intimidate force dancing clown',
#  'sometimes like talk sadness time want distracted friend laughter shopping eating nnmhchat',
#  'user without maryberry awful endofanera going 2b lost user bought lameduck notallaboutthemoney',
#  'bright side music theory teacher pocket dabbed said know whats hip walked away',
#  'user go one two way either get accept going change mope',
#  'peoplelikemebecause see happy exterior hopelessness sometimes feel inside depression anxiety anxietyprobz',
#  'thisisus messed mind amp im anticipating next episode apprehension amp delight isthereahelplineforthis',
#  'god need new goal keeper theyre horrific',
#  'user old age hope rest u destined become deatheaters nightmare',
#  'user wanted green potato bottle tag still plus soaking wet item delivered im winning todaysadly didnt',
#  'everybodys worried stopping terrorism well there really easy way stop participating noam chomsky',
#  'wow almost tmobile store san diego note replacement sadness need get mine replaced',
#  'worried felt safe unhappy',
#  'ahs every minute ive saying nope nope id gone move gtfo thank',
#  'nothing worse uber driver cant drive awful',
#  'leave rulenimber carpet cleaning furious worsethananatomicbomb accidentlyspillbeeronthecarpet',
#  'said ill say america really fortunate black people want equality revenge',
#  'user u know ion play shit bout weary brother',
#  'user user cmode grimrail made want eat angry bee',
#  'happy birthday user cheer cheerchick jeep jeepgirl idriveajeep jeepjeep cheer',
#  'user assure laughter increasing anger cost arrogance westminster',
#  'people even debating race inequality within justice system like non existent theyre trying aggravate u',
#  'contained depression new economic engine sustainability say joel user user vergecon newgrandstrategy',
#  'user gt huff louder',
#  'user lol thought maybe couldnt decide levity',
#  'there certain hilarity people angry protest national anthem flag act covered 1st amendment',
#  'dont want pity instructor id like understanding im truly trying despite circumstance make discouraged',
#  'communitysleepcoach look narcoleptic puppy make smile human amp find odd position seek th',
#  'user v atlanta yr v rockies dbacks yr thats combined v atrocious team nl awful',
#  'user user experience play role education preparedness fear',
#  'user appointment booked today waited day nobody showed also requested call back never got one awful',
#  'summer officially end today sadness',
#  'user seriously dude buy bubble tape phone snap broke another phone',
#  'user holy shitwhat hell happened lip fix shit mtv teenmom horrible',
#  'final vestige 90 childhood dashed shoal hearing house cover tracy chapman fast car dayjob',
#  'maybe entire russian team test positive meldonium north american get replace',
#  'hey folk sorry anything offensive got posted yesterday account got hacked fixed though hope angry annoyed',
#  'dreamthey trying steal kidney blackmarket whydidiwatchthat',
#  'made world empath unhappy',
#  'im nervous test rip',
#  'ryan gosling eva mendes finally b joyful funnydont bossdont arguedo everything kidsgo mini car trip focus love',
#  'embarrassed saw u like knvfkkjg think stalker n start waving cheerfully inviting u',
#  'wow one dad top favorite throwback rapper died fiery car crash today atlanta sad sad',
#  'cant wait listen new single mystery new album newmusic newsingle newalbum popmusic dark',
#  'anybody know good place book show montreal short supershort notice punkrock postpunk blue',
#  'dont afraid space dream reality dream make',
#  'finally leaving first job soon ive working since going kind bitter sweet',
#  'user user dont get started town centre used go every week month horrible',
#  'brawndo cure depression user idiocracytoday',
#  'rejoice birth grieve funeral person involved mark twain',
#  'dislike people get offended littlest shit',
#  'user look adorable awe',
#  'new play tonight pretty much blind run played game maybe got level rage horror',
#  'user ur road rage give anxiety',
#  'user brings back great memory hilarity saturdaynightlive',
#  'user user god user full shilling seriously need major rethink lab gove lifetime sad',
#  'significantly bitter smile let',
#  'user trying go home tonight run 2nd run 3rd thats champ dosike loser terrible',
#  'user didnt many chance show looked lively good shot tipped bar end',
#  'need advice get rut needmotivation',
#  'health think depression feel like',
#  'user itll easy spot parade tiny weans expensive jammies really hilarious',
#  'muscled man huge heart messing brain heart lost confused',
#  'user user user trump say refugee situation terrorism quality life take note',
#  'user im wearing black tomorrow mourn',
#  'user he right civil war start wall wall terrorism dont fancy muzzys chance',
#  'user laugh louder time shaking head really cheesy wasnt',
#  '4yo gone blast gothcore music anxiety amp cant listen around bcuz spooky sigh momlife',
#  'user glee',
#  'gloriosa bazigaga rwanda work lost relative genocide yr peacebuilding given optimism within power',
#  'user mhchat childhood experience inform adult relationship associative memory question ability process',
#  'texan astros shut tonight houston back normal texan astros sadness loser',
#  'user nick fury',
#  'im dream said something really retarded twitter got like retweets nightmare',
#  'user user dont get started town centre used go every week month',
#  'user scrap rage instead',
#  'told wife chance would sydney team afl grand final response there two sydney afl team serious',
#  'user wow im really sadden terrible',
#  'meet new people grow reality people desgusting fake lost cheerfulness started',
#  'urgent need get new job constant gloom current one getting bit ridiculous',
#  'girl playful childlike seem lovely relationship cant imagine serious convos cute',
#  'im absolutely love laurie hernandez shes adorable always cheerful',
#  'windy glad didnt ride bike fear wind',
#  'point living optimist foolish enough believe best yet come peter ustinov optimism quote',
#  'user user quite response retaliation weiner getting revenge huma amp hillary clam diggingnallscumbags',
#  'user user theyre pretty awful look historically',
#  'broken policy blasio ltgt trump giuliani broken window part pecking order bully politics america resist motto',
#  'mate thing get excited profession mad client said opened bowel im rejoicing',
#  'user dont know nervous see',
#  'user worst going morgue positive id horrible reuters',
#  'user one thing attacking hating worse make u like angry vengeful behavior detest',
#  'user wow right need helpso im getting laureliver fandom bitter comic fandom',
#  'im shy girl',
#  'im kinda sad hope shake school',
#  'every day think house burning always neighbor burning toast',
#  'fact sometimes dont get furious people wrong get furious fool',
#  'user nothappy still charging fullprice fuming bestrides',
#  'everyone raging',
#  'sometimes get mad something minuscule try ruin somebody life like lose job like get federal prison anger',
#  'user user ref gts favor tonight',
#  'nls top bureaucrat director group formed oppose nls top megaproject nlpoli never dull',
#  'watch amazing lively broadcast user musically',
#  'one want win wild card play cub road sadness',
#  'user user amal clooney try prosecute bush blair war crime turned world upside downampcreated terrorism',
#  'user stop press user saidproposed something racist shocking',
#  'user nisnt obrien supposed sort offensive genius',
#  'good morning chirpy springequinox pensive sister autumnequinox perfect day however expressed thebeautyofbalance',
#  'user think swallow swift gone photod night ago seen since sad autumn',
#  'told chiropractor im good time long time questioned habit yet unnerved doctor',
#  'lady gaga fucking followed waiting day age fucking happened im shaking thank much user',
#  'user came silly oclock woke thats happened wasted fuming',
#  'user user gleesome threesome',
#  'user think get fashion police involved shocking',
#  'wishing rich didnt get morning poor sleepy sad needsmoresleep',
#  'user relentless echo chamber negative comment lot reverb typical bully behavior',
#  'user thank follow good website cheering hassle',
#  'user people much negativity filled inside im always happy gloomy world someone like u exists namjoon',
#  'something make excited terrified thrilled nervous elated amp like youve kicked gut need word',
#  'user thats easy blow lt run play created seam sua burst',
#  'user user decided bit lackadaisical getting dressed get grocery',
#  'user optimism hell lose thats actually compromise p',
#  'user nit alright said cheerfully trying make moment fun',
#  'user might get donal g sure wont cork he fiery dopey frank amp cult',
#  'ppl like irritate soul',
#  'user least character fast furious pumped adrenaline franchise thats',
#  'user snapchat back constant battle see get ugliest snap one another snap survival',
#  'user he raging type properly ha ha',
#  'pakistan continues treat terror matter state policy say user uriattack',
#  'much hair nightmare also soft guess winlose situation',
#  'user user whatever sam holding tee look like got droop',
#  'one step forward two step backward link rogerfederershop doesnt work losing hope roger federer new website sadness',
#  'pat awesome belichick awesome',
#  'dont join user put phone talk rude taking money acc willynilly',
#  'user user user user take 2k number madden low dropped people unhappy',
#  'user yall mean rioting fire starting business burning looting asshole create blacklivesmatter',
#  'hm pinafore timenni need mirth',
#  'grim despair feelingi look self family hubby fought year country ive worked year govtgt',
#  'coincidence turn tv etcamp listen amp watch objective captureyourmind fear amp depression findgodnow',
#  'turkish exhilaration shade irruptive russian visitor twelvemonth gobbler nephalism',
#  'week full monday end disheartened',
#  'user im history people im ive bullied one make three post attack bully',
#  'user way go london nice job electing muslim jihadist mayor good luck future terror attack sadiqkhan',
#  'pull tonight make car shake',
#  'feeling gloomy',
#  'b day next week catch sauce watch heaviness',
#  'carry wayward son therell peace done lay weary head rest dont cry supernatural',
#  'user cyber bully',
#  'user found first episode bojack incredibly funny got le funny stayed drama',
#  'page script due friday class said could mfa thing gradschoolproblems someonetelltinafeytohireme',
#  'riggs dumb as hell lolol hilarious lethalweapon',
#  'user bully',
#  'india react uri attack revenge',
#  'well stock finished amp listed living room moved around new editing done amp fitted visit inlaws productivityatitsfinest happy',
#  'user outrage black child get killed crossfire black shooting',
#  'user rabid dog ridden child eaten flesh one fellow limb adult',
#  'user watched cobbler load season gorre pro footbaler terrible',
#  'putin feel acceptable bomb amp kill aid worker soon may sitting table trump armageddon usapleasedont',
#  'people gotta start much drama shoot',
#  'miss fact burkeramsey swung amphit sister jonbenet face golf club previously fit',
#  'poor blue bell sad',
#  'user user muslim usa age think muslim commit terrorism due islam gotta mind',
#  'user angry student racist teacher stopping class letting go',
#  'think youre good go already dont worry',
#  'wine drunk worst version ffs dont even remember seeing basshunter',
#  'bounty hunter thing bit lively',
#  'feeling get know information scared might bad test collegelife nervous',
#  'user supine pianolips parted sixwordstory amwriting blue singer',
#  'user thanks ryan amp brad scary shit u first episode dont think heart make s6',
#  'always borrow money pessimist doesnt expect paid back',
#  'pax enjoyed gloom user user',
#  'condolence jc george family',
#  'user snap seems problem',
#  'user nlikewise death cutting despair',
#  'gonna give k police bitch minimum sentencejust wattch',
#  'feel like appendix dont purpose depressed alone lonely broken cry hurt cry life',
#  'travelfail virgin virginaus etihad nightmare also delayed obvs',
#  'tulsa police manufacture murder wonder carry burner maxlevelz',
#  'dehydrated exhausted stressed still blessed optimism',
#  'u need band together apart nevertrump promotes hatred fuel',
#  'user fucking dreadful live footy match',
#  'user user nbecause distrust life argentina lot heart president worth every vote',
#  'shes foaming lip one hip user one many great lyric',
#  'user guess must really expensive whole family stayed poland really miss',
#  'user user user user user understand concern look foundation contribution',
#  'someone let snake house bet user kill bugger get hand huckfp',
#  'fake people irritate',
#  'user fmf protester arent interested reasoned debate intimidation violence amp disruption get demand met',
#  'lunatic asylum place optimism flourish',
#  'damn gud premiere lethalweaponfunny serious',
#  'user user bully',
#  'appears fire alarm disapproves cooking style',
#  'going get city next round revenge',
#  'trump afraid big bad hillary election presidentialdebate presidentialelection orangehitler skip hide coward fear',
#  'user sitting wrapped fluffy blanket incense burning listening bon iver drinking mulled wine im',
#  'petition nonmaghrebi poc stop buying couscous white grocery store boiling couscous trash',
#  'user thank happy birthday well',
#  'watch amazing lively broadcast user musically',
#  'user well ceremony next time meet itll involve burning something possibly booze andor caffeine',
#  'dear user please tell bus driver obstruction side dont pull oncoming traffic causing vehs swerve fuming',
#  'alternate reality user comment section give poem cheery thumb disappointed thumb',
#  'user may suggest meal made bean onion amp garlic day class revenge',
#  'highly suggest looking online company help send youre package overseasdo ever ever use user',
#  'began squirm beneath user struggling get relentless grasp realized attempt useless',
#  'remember reflect reginald denny night much like like charlotte think gun lobby must rejoicing',
#  'user user looking forward user opened stuartspecial literally yelled tv umbrage',
#  'something opening mail justvery pleasing',
#  'doe run opposite side depression',
#  'user awful music take walk right cliff k',
#  'day elated im taking pto tomorrow im done',
#  'pessimist see difficulty every opportunity optimist see opportunity every difficulty sir winston churchill',
#  'user dont think ian knew pavel knew charlie bet rob cackle glee heard happened thearchers',
#  'user maybe constipation issue know date relieve affliction way jose',
#  'user smh remove ideologically bankrupt opportunistic establishment theyre burning bridge social contract anger',
#  'user lost xt nova around hole sadness',
#  'unga pakistan clearly show face cowardliness blatant lie time india act upon terror',
#  'aqw shouldve always stayed art style competition create detailed art time',
#  'user mine party decide party slowly transformed vengeful hellcult white male resentment',
#  'user user user kirbys black panther cool animated panel',
#  'cant fight elephant wrestled pig quoteoftheday',
#  'flat party instantly get bollocked fuming',
#  'user betelgeusesloth lively dedicated tenacious regulusgreed humbly content leygluttony starving hungry',
#  'user ldf shall weekend spraypainting greenwichmarket user core lilylou fret amp benoakley',
#  'user awe man free',
#  'user wanna shake tree',
#  'user isnsure mind clouded',
#  'user gotta fast n furious',
#  'ffs thing come back haunt cringe bad cringe terrible gun',
#  'never let see frown',
#  'country gave safe house osama bin laden dangerous contained pakistan terror heaven declare user',
#  'gadot please put left turn signal williams ivan allen jr blvd absolutely ridiculous atltraffic',
#  'thing feed naay raging something brother filling gap',
#  'haikuchallenge haikunnthe crisp autumn airnmy freedom purchased deathnno one mourn',
#  'honestly feel nothing towards either parent pretty depressing',
#  'could turn anxiety offi would nooneunderstands',
#  'user maybe dont provoke future want run risk punching board',
#  'karev better seriously done done user angry unfair ugh',
#  'worry theyll get glass guy bill u',
#  'user im really excited november hope theyre horrid chavs though',
#  'user terrific game fazed mcfc',
#  'user user user threaten pussy',
#  'user fucked coupon goal',
#  'reflection grind real working job amp school ksudsm ksu recruiter instructor tumble cheer gradschool',
#  'aberdeen st johnstone let see punt furthest awful',
#  'user stumbling block pessimist stepping stone optimist',
#  'listening joey really help anger',
#  'user thing either unproductive unhappy deal video badly',
#  'another joyful encounter tribez amp castlez met bartolomeo want know download game find',
#  'user user user yes exactly amp he sold country terror lying cover',
#  'woke nightmare 3am couldnt sleep took useallthehotwatershower time read',
#  'got tip drunk uber passenger today get parking ticket id blame karma dumb as forgot pay meter',
#  'pat awesome belichick awesome awestruck',
#  'david gilmours biggest compliment bb king asked gig born mississippi pinkfloyd theblues davidgilmour blue',
#  'seriously hope chance celtic missing going come back haunt alloa sucker punch',
#  'hate little girl got lot growing fuming',
#  'threw sedate damn horse tranquilizer',
#  'user like started college horrific probably get better dont give yet',
#  'user user hey stupid bad intel take bin laden try faux outrage bet u admire putin right',
#  'biggest fear incurable std pregnancyi mean theyre basically thing anyway forlife annoying weirdsmells',
#  'howl moon user user next wednesday 28th free double feature silver bullet cursed horror',
#  'two blanket hoody still eternal sunshine mope',
#  'india want shake hand pakistan usual pakistan cheat every indian nnshameless pakistan',
#  'user depth youve sunk youre readership deserves',
#  'user exhilarating hockey theyre still russia win regulation im reading fuck',
#  'wish stayed da gump ill make panic like last rapper',
#  'projection perception see someone else also level within anger',
#  'user actually maybe supposed die donation saved life optimism',
#  'follow trump certified bully question child may go war v consumate diplomat user',
#  'user tunnel shudder think grimy tweet',
#  'user disney animated musical film thelionking influenced williamshakespeares hamlet song eltonjohn',
#  'lt moment finish netflix series nothing else watch depression',
#  'im tired people telling worry fact probably never gave fuck',
#  'user user aa right passage come n word insult church ignorant',
#  'user sadly war often factor jump start u economic growth',
#  'someone rudely say woman long hair inner feminist try rage',
#  'animal animalsntrap trap trap till cage fullnthe cage full stay awakenin dark count mistake',
#  'slow anger better mighty rule spirit take citynp bibleverse pride',
#  'million box office doesnt movie justice political snowdenmovie terrific thriller love story user',
#  'upping room make apprehend leaving charcoal ownership unzu',
#  'user user yeah received fine today furious currently appealing member long',
#  'grudge youre holding keep making appearance god want deal',
#  'user shock horror handicap dodger top close agg cup good think pressure get mark',
#  'im girly sense always lash amp nail done tomboy sense black color amp refuse ruffle life',
#  'harboring osama bin laden relationship haqqani network enough evidence prove pakistan sponsoring terrorism',
#  'man know juggle didnt ball itnfunny pun punny lol hilarious',
#  'user droop saw naked wrestling asked get hole one jaymohrsports',
#  'user got staystrong smile yourebeautiful',
#  'nothing else could possibly put damper day xrays someone kickin as breath',
#  'user concept gay magazine feel like cover terrible people theyre gay voice seems upside',
#  'user easy ride child cry noh find mefind nothing nwe sullen misty moor',
#  'user thought provoking amp lead one question really happenedvery sad',
#  'migraine hangover day stood dish im exhausted gad depression amp chronic pain anxiety depression pain',
#  'hour football practice boiling sun 2hr volleyball practice boiling sun',
#  'thats start season thats open show show dark hell get empire',
#  'might leave aggravate bae',
#  'joyful tambourine ceased noise jubilant stopped joyful lyre ceased isaiah',
#  'boyfriend forcibly stopped anxiety coping method holding forcing hand kinda stuff',
#  'user ended paying 75p half tube smarties dont even get pleasure popping plastic lid either',
#  'internet age get mad proportion assume terrible worst little fact knowledge',
#  'user user user user user awe feel bad naive ou worst',
#  'rooney whipping boy mufc sad',
#  'user start buying death wish coffee shake hand espresso every',
#  'user cheer',
#  'user im sure youll heyday',
#  'user user user user user user give key back arent house shocking',
#  'obamalegacy weekly riot terror attack gt400k dead syrian jew fleeing persecution europe christian genocide',
#  'drop snapchat name bored snap swap pic',
#  'user user lestweforget yr graduate trainee recruitment concluded disappointed weary however wewait',
#  'happy birthday user cheerchick jeep jeepgirl idriveajeep jeepjeep cheer',
#  'user omg im slow bc eng well hand shaking uhh help im like lil chicken moreisbetter',
#  'user android app designed buggy work sporadically fire tv box',
#  'user user user user dont provoke voke',
#  'user badi fearing life',
#  'user dont see difference courting appealing woman v deception amp pressure depressing',
#  'user customer service got involved eventually completely wash hand awful dreamornightmare',
#  'look massiah youngleadernpakistan massiah terrorism',
#  'pretentious dick night gallery fucking used towel dry sink',
#  'another day another flight swear last ever user flight take love flying easyjet horrific alwaysdelayed',
#  'user sorry hear issue making feel dont like hear customer unhappy',
#  'fear truth even gloomy counterfeitberl katznelson',
#  'miss gran singing rawhide deep baritone growl',
#  'egyptian official expressed frustration outrage obamahillary administration support muslim brotherhood',
#  'two major banking stock almost high benchmark still close top sure worry market',
#  'batman animated series gift 90 animation god',
#  'user control avoidmmt guy terrible',
#  'didnt impress didnt depress',
#  'user user couldnt care le gotham havent watched since mid point season horrible',
#  'user user user yes bad point racism lest provoke racist racist indeed like',
#  'seeing alex revells face get angry',
#  'user user user user dread think dirtypeople',
#  'user get going tag link please lot friend love following unintentional hilarity',
#  'addition fiction wish luck research paper semester page oh boy daunting',
#  'user cant read article headline indicates horror story lock sick chavs throw away key',
#  'user user live life devoid mirth come think arent enough taco bowl life either',
#  'trying book holiday flight user website becoming nightmare',
#  'user john kerry fckd uchief justiceofpak made statement publicly party supporting terror else u needterrorstatepak',
#  'user jeezus god dark',
#  'ive realized anxiety time high im office feel prisoned pick bad energy',
#  'r u scared present front class severe anxiety whats r u sad sometimes go get ur depression checked imediately',
#  'user today impact signal im afraid engineer working resolved evening youll',
#  'oh dear evening absolute hilarity dont think laughed much long time',
#  'wtf united shocking defending',
#  'amateur sit wait inspiration rest u get go work stephen king author serious writingtip',
#  'jesus wept another rn rusty user quote price sensitive news price sensitive news etc etc ramping',
#  'perfume smell like smell smokey incense would',
#  'user personally liked relentless didnt get ourhouse onejersey werealldevilsinside ndoes nothing till puck drop njdevils',
#  'scorpio always seek revenge',
#  'user user lmao awe sad',
#  'appropriate first secretary permanent mission tasked demolition terror state pakistan like renunciation lie bit',
#  'user meden frowning non existent face',
#  'user dwts make night every show',
#  'still shaking though',
#  'arrive office day first ever festival internet panic',
#  'drunk hid key well sober couldnt find anywhere',
#  'theyll yo friend shake hand kick yo door thas way game go',
#  'depressing darker much earlier',
#  'got asked hoco instagram dm bc someone lost bet love maturity people grade',
#  'user say attract see maybe shouldnt pessimist dont wanna take chance lol cant wait relocate',
#  'user seriously digging eyebrow animated',
#  'taurus female beautiful sparkling jewel glowing moonlight',
#  'user telling racist bigot always resort insult fag like thats worse racist bigot',
#  'watch amazing lively broadcast user musically',
#  'user gay guy dad revenge fucking',
#  'user listen someone tie like awful',
#  'dont talk politics people nowadays get offended easily',
#  'user shes jogging bit stay beside puffing cheek huff time oh jeez jasper dont',
#  'user user user user hell defend belt aldo hard u grudge holding bitch',
#  'user liked moping around episode moment emotional weakness felt sorry',
#  'user wasnt joke',
#  'time remove cb team somehow screw rip bandaid itll sting bit everyone get',
#  'user user user user gotta shake booty instead though make sure good',
#  'user theyve officially said episode left future despair delayed',
#  'user oh hell jealous got paid fuck whole new level love conflicted',
#  'watch amazing lively broadcast user musically',
#  'well evaluation came back minimally effective student test score parcc sunk eval time quit teaching',
#  'majority people irritate fuck cba people ahahah',
#  'omg actually thought going jump southpark southpark',
#  'never make decision youre angry never make promise youre happy wisewords',
#  'user watched great wall hilarious',
#  'everything see american police training seems calculated trample human dignity inflame outrage escalate confrontation',
#  'user dhoni bcoz calmness nd match winning finisher nd proud miltirian dadhusband nd wonderful humanbeing nd smile',
#  'user point voting trump push piece board game like angry toddler wreck everything everybody',
#  'user user rare officer shoot without regard dont want conscience incite',
#  'tf broke boy keep tryna find gfs get ur fuckin right b4 smack yo bitchass deserves 2be happy amp u dont deserve as',
#  'user hey breezy wanna give coffee posted snap please',
#  'user would great card crash happened twice nightmare',
#  'nothing like shower power go creepy',
#  'blood mucus choke swallow mirth cut short wrong answer take awkward movement user',
#  'im moving weekend amp sugar daddy replace nigga still happy',
#  'user joke pay data im spain text say ive used data terrible service',
#  'user dont understand express emotion others may lead sadness loneliness amp neg impact long term mh mhchat',
#  'user im sorry heartbreaking scary happen happen anywhere please safe',
#  'user user ive got teampaella present way fi dont think theyll arrive saturday sadly',
#  'cheerful heart good medicine crushed spirit dry bone wicked man accepts bribe secret pervert justice',
#  'side effect fighting disrespect come ignoring person show dontcare sweet revenge',
#  'welfarereform model snap',
#  'user control avoidmmt guy',
#  'truly feel like science ability make milk anything cashew milk hemp milk pine nut milk dandelion milk',
#  'user user team must draw hat daily personality drugged yeller quiet screamer',
#  'isi reference scrubbed federal complaint suspect nyc nj bombing appears omit terror name bloody journ news',
#  'free live music dc tonight blue moonshinesociety user loft starting 1030pm user user',
#  'espn assumed wanted free magazine',
#  'third year college student english major today first time ive ever written essay without panic attack',
#  'user dont leave sad',
#  'honestly dont know im unhappy time want stop itnevergoes',
#  'real sjw let america downni found u go get usni let let inni rage lolnsergiosarzedo',
#  'neighbor dancing clayton home commercial hilarious',
#  'user yuhh plus clin ep prevmed uggh hahaha',
#  'user ended paying 75p half tube smarties dont even get pleasure popping plastic lid either outrage',
#  'rooney whipping boy mufc',
#  'user user horrid disease maternal grandmother sister suffered affliction hard',
#  'side chick trying fuck u like going forget wife done',
#  'praying lord keep anger hate jealousy away heart sign maturity conciseness',
#  'dont get close dark inside',
#  'user u tried boiling em take year',
#  'loving user user talk challenge fear map inspiration stayunstoppable',
#  'hard get touch user one simple question cant find answer website hour waiting online chat',
#  'seem alternate sleepfull sleepless night tonight sleepless one insomnia notfair',
#  'user sam yes helpful need sorting asap keep promising stuff doesnt happen fuming',
#  'user help maintain boost status world class centre education culture tolerance',
#  'user getting lost dont want see eye hungary huffed crossed arm looking away angrily',
#  'user apparently contact sofa meant delivered today old one gone sitting floor sofa fuming',
#  'user nearly started cry full panic attack tatinof bc crowd feel',
#  'ffs tate thought wind willow serious play cant wait see play singing badger',
#  'user congratulation free month activated charge month absolutely furious',
#  'cop going pull gun reason threaten able merk as walk away',
#  'user jeezus god',
#  'need help anger',
#  'got done watching jeepers creeper epic horror horrormoviesarebest movie movie horrorfilm',
#  'tho havent talked jeff news sad shocking rip jeffrey',
#  'second day job already got dollar tip dude whose constantly twitching eye lololol cheering',
#  'look u smiling photograph see secret behind fake smile facta fact life',
#  'week still go depression smh',
#  'left maine sadness',
#  'user grapefruit squash gonenot able get week unhappy',
#  'howl moon user user next wednesday 28th free double feature silver bullet cursed',
#  'often disturbed people find appropriate acceptable funny cute adult find stuff humorous sad',
#  'worry master haddon robinson user jesusisthesubject anxious',
#  'love take mask fear cannot live without know cannot live within james baldwin',
#  'wouldnt anger issuesif didnt lying issuesthink one pow lie confusion',
#  'doe run opposite side',
#  'worst juror ever michelle nicoles biggest threat bitter bb18',
#  'user he stupid hate lol bitter',
#  'people trying hard hate cam newton without understanding position sad',
#  'angry shouting match pessimist amp optimistnyoure half emptyheaded user nyoure half full user',
#  'user enliven soul',
#  'next hour waiting ourgirl start user',
#  'user user user user user user user oh god brewer horror horror',
#  'fucking hell rush damn train also use fucking 4min wait still sweating smrtruinslives',
#  'angry',
#  'love people say arent racist right say racist shit work fuming',
#  'sometimes think british political landscape desolate look foaming wasteland u think ok',
#  'user user two ten time interesting particular afternoon goofball could say worse umbrage',
#  'user user clown neighborhood creepy enoughisenough',
#  'user eh guess want everyone ive ever burst laughing front',
#  'bos like stand office amp smile like shark maliciously gleeful ask secret tell',
#  'amwriting horror dark loud creaking door noise coming kitchen door creak wtf',
#  'anger acid harm vessel stored anything poured anger nnmark twain',
#  'user u guy determine team cause im shitty team play im fuckin cod',
#  'user user offering moth warranty ps4pro truth ripoff',
#  'user u diver named steele johnson id like barred olympics',
#  'go restless',
#  'user give gas dont hate u dont respect ur rudeness bully',
#  'whats box search google chrome distracting',
#  'wake scroll social medium another father taken child everyday keithlamontscott',
#  'user buzzing pathetically sympathy let twirl moustache chuckle sting psychowasp',
#  'user terrible',
#  'user im surrounded trump voter youre right fucking terrifying redstate',
#  'democracy doesnt workn mob mentality mass hysteria mongering oligarchy',
#  'get shot lingys face time pretty sure would red hair pretendinghesok ruok aflcatsswans',
#  'user user give smiling emoticon ya dont like idea frowning gtlt',
#  'indian uber driver called someone n word wasnt moving vehicle id jumped disgusted',
#  'user user welcome ji sorry word irritate u',
#  'asian tiger mosquito relentless aggressive kind dealt kid',
#  'goddamn headache anger',
#  'never forget 5live cancelled program allow extend people could call detail outrage behaviour',
#  'glad didnt watch smackdown cant see men user user lose sohurt revenge',
#  'lmfao user racepimp tamron hall used word fscts msnbc sentence libtard biasedmedia neverhillary',
#  'hate guy cant control anger',
#  'caught user wonderful new series ealingcomedies infectious delight every interview film clip',
#  'ranger v celtic revenge',
#  'user unless concern people figuring wtvr reason dont see shouldnt tweet thing',
#  'user user user user interview scare crap never imagined many dumb dumb american',
#  'omg kissed w',
#  'user gabe worst part cant get hot status month there chipotle near enough campus sadness',
#  'lot would give ghandi road rage',
#  'forced fake hug someone didnt flinch get litigious past awful',
#  'user worst exec complaint ever horrific customer journey',
#  'ghost stefano reflects grim indignity murdered corrupt cop faux love day',
#  'user user user bully bullshit fullofshit please take garbage',
#  'user look completely rabid user',
#  'user im always little bit weary speaking dont want hijack convo lgbt person ive seen',
#  'user shameful display watched today left reeling much anger dt feel like exploding clown watch',
#  'elated celebrated like obama waited last day office tell nation brother getting reparation',
#  'user doesnt offend weird',
#  'user hit sink hammer sorry universal modifier',
#  'user received verification email asked resent time still nothing',
#  'user would get decent referee shocking',
#  'user forget hair salon look light amp cheery would go coffee amp read book',
#  'user nif room burning',
#  'user user candy corn greatest candy world come objectively terrible',
#  'insult late sherri martel',
#  'hate dont start conversation wont one',
#  'user yes hun avoid cost',
#  'grown adult doesnt drink never drank assume raised around raging alcoholic want part',
#  'happy 69th user may u keep haunting u many year horror writing',
#  'user terrorism shouldnt way life united etates wasnt islam brought islamexposed islambacon',
#  'watch amazing lively broadcast user musically',
#  'mourn creativity lost',
#  'user take deep breath bc shaking could adrenaline oh wow thats weird depending youre regular varies',
#  'sorry guy absolutely idea time ill cam tomorrow keep posted',
#  'poor blue bell',
#  'user user honorable senator cheering cease fire hold people die cheer genocide support good',
#  'professor introduce say one interesting factnnhi im ethan sun engulf planet fiery explosion one day',
#  'ignored broken tooth long abscess need dentist fear make hard go45 still cant go dentist',
#  'dont know whats worse new pizza hut commercial pizza pizza hut make horrible',
#  'user user user hooked backward recommended smoke',
#  'follow girl tiff got follower user',
#  'getting excited user play main stage sunday oct jazzholiday riesbrothers rock blue jam',
#  'love megan raging kendall jenner photo im sat like',
#  'think anger barrier truth user',
#  'new play tonight pretty much blind run played game maybe got level rage',
#  'user user yes rejoicing',
#  'forgot plug phone overnight nightmare',
#  'war right outside door rage usatoday',
#  'folk band thistle replaced paul edward quartet laurel bank park sat 11am 3pm due ill health jazz blue',
#  'user haha sorry grim even disturbed amp im starting lose trust twitter generally',
#  'youre scared press send bgoodthepoet prayforme thisisagoddream career help heart heartracing',
#  'competition suppose motivate better everytime bitter time de philosopher dj kyos nquote success csgo',
#  'mind dark roomndeveloping madness',
#  'whats worst affliction someone know ever convinced',
#  'warning sensitive angry insecure baby today ugh people large either hate ignore bc literallythe worst',
#  'like really fucking asked offended',
#  'user haha well today cant get beyond pout annoying im afraid',
#  'say third city kit fucking awful someone nike want shooting',
#  'damnnit gonna pt shy chief reward getting post game photo',
#  'want canada rn awe',
#  'user user user nno wrath',
#  'user user user way blood boiling little bastard',
#  'user user user im sadly im smutty',
#  'user user drugged raped woman least barb sober consenting',
#  'user awe yay wish could rt',
#  'user dull',
#  'anger wrath intense emotional response',
#  'im point life im playing christmas music room need winter joyful time rn',
#  'chart music pretty much',
#  'mom remember narley died cried like baby',
#  'user user user dont listen white trash talk black insult talk race living trailer',
#  'alarm clock ringing morning n flatmate knocked door asked set anything fire im burning alive',
#  'bad anxiety annoying',
#  'overwhelming sadness shall pas lonley startingover',
#  'second day job already got dollar tip dude whose constantly twitching eye lololol',
#  'everything far away time short rest weary',
#  'user user well courseprogress sake progress must discouraged problem substance rhetoric',
#  'confiaejce come always right fearing wrongpeter mcintyre',
#  'love tay amp tiff sitting house im work',
#  'user aint serious houvsne awful igotbetterthingstodotonightthandie',
#  'harking back dts challenge user givedt hearty thank youif release tax return',
#  'user cheering user user',
#  'wonder wolfcreek tv show sponsored antitourist board australia discourage visitor stayathome dontvisit',
#  'shame fear matter face',
#  'user mhchat childhood experience inform adult relationship associative memory question ability process sadness',
#  'user maybe itd different stayed sixth form still oppressive architecture uninteresting people',
#  'user content update provoke income',
#  'user user lost like really big deal dont worry trivial shit like',
#  'user talking expansion gear fury always well towards end',
#  'thoroughly enjoying ahs tonight ahs horror americanhorrorstory',
#  'user user shocking work ethic player rooney stifled laziness',
#  'cant believe user cant put even point user horrible hugeletdown',
#  'lgbt person tell someone else identify isnt valid sad everything stand',
#  'feminist ask theyre unhappy lack love life bc fighting losing game',
#  'know final day summer finale user sadness',
#  'thought xbox one madden bundle would come physical copy madden code gonna take fucking forever download lol',
#  'user user user shit gonna start cold war flag first',
#  'user childood experience leave permanent deep sadness adult underlie everything mhchat',
#  'forever straight fix frown u good user',
#  'early morning cheerfulness extremely obnoxious aldub 62ndweeksary',
#  'n word normalized medium wow word word frog boiling pot via medium',
#  'guess bradangelina gt anger gt blacklivesmatter',
#  'complain time wonder people never want see acc rile stfu',
#  'user user get wrong fur pal shocking',
#  'dont let worry get remember moses started basket case lol ntoday choose faith fear moses',
#  'user user evil rich white men fucking crony intelligencegovacademia using blithe black fodder',
#  'maybe entire russian team test positive meldonium north american get replace optimism',
#  'headed mdw w layover slc got food wrong move bailed food amp barely made user wannagetaway contest sad',
#  'literally make depress tbh',
#  'wish next madden story mode like fifa',
#  'grow weary goodnnbillclinton',
#  'time go hit library lovely pile book reservation collect morning glee book reading',
#  'bb18 michelle cry shocking bitter he teamnicole',
#  'need think new avatar fire emblem revelation might start playing soon idea name gender choose',
#  'user user user user please could clouded passion emotion lead truth',
#  'quinns short hair make sad',
#  'drop every fear',
#  'sometimes best motivation come proving wrong energy relentless motivationalquotes',
#  'dont know make pakistan fear terrorist terrorism terrorstatepak',
#  'day lost',
#  'struggle affliction youarestrong amp youarearising',
#  'nana hoco bc dream since freshman year awe user',
#  'someone make priority list thing outraged order racism animalrights abortion cop',
#  'user dont know try fret sweet little pupper',
#  'people weak follow dream always find way discourage',
#  'red card gordon ref must celtic fan shocking challenge',
#  'seeing ripshawtylo got thinking bout rapper thought user dying burst tear smh',
#  'user peanut butter take away sting',
#  'angel got nervous',
#  'patti seems sad stamped ran behind sofa give plenty love affectionmore usual sad',
#  'offense doctor cry tear joy realizing family christmas cute',
#  'user reaper became reaper find story wiki thru comic animated short',
#  'user user user might sting bit lad youll get betterwithsinnfein',
#  'user yeah whatever whahibbi muslim sect know islam synonymous rape terrorism',
#  'hour user ride make sorry',
#  'wish kid stressful part whether gabriella troy would get back together hsm nightmare',
#  'strong hand moving firmly grope user thigh squeezing digging nail extract growl',
#  'rojo hilarious',
#  'user look fab made big screencant wait see evolve amp bright future little toy people',
#  'bad kurt literally',
#  'user user ref gts favor tonight terrible',
#  'sorry burst anti allo spam fuck messaging app launching without encryption default',
#  'halfway work realize forgot put underwearits going one day mombrain toomuchgoingon longday',
#  'sad im rejoicing collegekills',
#  'alien zombie gore slash ghost sith horror love',
#  'tell im supposed feel broken hateful guilty love sadness',
#  'zika hoax file deet part binary chemical weapon targeting brain toxin fear neurological uscitizens insect mammal',
#  'even pencil never stayed end',
#  'user wheres outrage party nominated lying corrupt person received donation nation support terror',
#  'forgot bb18 tonight much real world distracting horrid',
#  'user user user user user goddamnthe celebrity draft end classic hilarious',
#  'ugh asleep yet fml think low key im afraid might miss something sleeplessnight sleepy restless',
#  'often disturbed people find appropriate acceptable funny cute adult find stuff humorous',
#  'become verb im gonna villaseor old contact dont need anymore sadness user waitingforexplanation',
#  'marcus rojo worst player ever seen useless toasting burning bastard',
#  'bcwinechat whats common method used make bc sparkling wine',
#  'step comfort zone ngo risksnface thing fear nnthis life start happencpd',
#  'user asked gate crash dumb idiosyncrasy sober people analyzing situationnbanobee user',
#  'shouldve stayed school cause aint nobody',
#  'user user word terrorism',
#  'teen son left car get haircut im praying storm make home safely sad terencecrutcher',
#  'user hannah stop mournful chill',
#  'reverse half way wood collect dog n ive never even reverse parked life nightmare',
# ...
#  'user user supporter user prejudice disabled people disabledlivesmatter bbcnews skynews',
#  'user hope police met subway took straight jail awful',
#  'know much hurt see best friend sad',
#  'mom recorded nightmare christmas love',
#  'user user blaming fucking idiot putting world middle tantrum one',
#  'user oh nomorehammocks nightmare',
#  'eye dilated hate world right rage thousand fiery dragon need drink',
#  'think youve got together day randomly burst cry',
#  'user lmao imagine frown across face hilarity',
#  'breaking hive first time since college final anxiety suck',
#  'qampa n christie user fr user would peter dardanella think u knowing poorthings',
#  'ive seen elder watching community hour honestly dont idea assignment apprehensive',
#  'user tried turn alarm morning turned alarm instead',
#  'user know wasnt optimist would despair',
#  'user user new campaign slogan ideai know bully trump yourefired deflect',
#  'user user user user thought sunk teeth something thats meant 2b sooked',
#  'smokeys dad sad',
#  'user made laugh quote sort rueful way',
#  'thenicebot wsjnordics make world joyful place thenicebot',
#  'going home depressing',
#  'ef whichever butt wipe pulled fire alarm davis bc sound asleep pissed angry upset tired sad tired hangry',
#  'jimmy carr make want cry cry shiver',
#  'express deep concern suspension user please reactivate never violated troles user',
#  'working blanchardstown shopping centre year figured today mark amp spencer lost',
#  'dont afraid give good go great john rockefeller quote inspiration afraid great motivation',
#  'user joke cut internet early mistake dont reinstate longer need engineer fuming',
#  'marcus roho dreadful',
#  'someone tell needa smile like excuse im frowning even harder happy',
#  'np rum rage',
#  'tell truth make someone cry better tell lie make someone smile truth lie cry smile offalonehugots',
#  'yall hyped abt girl getting hang w jb clearly look unhappy bored pic offense lol plus hate yall',
#  'trump supporter hillary hater wanna chirp weak minded pandering liberal tweet user user',
#  'bus car crash im still shaking bit week absolute horror icing cake terrible',
#  'user wouldnt cross street piss server dire',
#  'dont respond email within fay wifl killed animated gif girl ring',
#  'heard movie bob furious skittle analogy upset wasnt actually skittle',
#  'internationaldayofpeace white supremacist terrorize everyone differing culture online continue offline tomorrow',
#  'candices pout get preposterous week week gone bit jack nicholsons joker gbbo',
#  'bake tv match phone nightmare im stressed gbbo ntfcvmufc',
#  'even walking around family member carry gun make nervous theyre family',
#  'tierney reach deep cross back post play back across alloa defence clear celtic relentless',
#  'sad day 1st day falli dont dislike falli love summer firstdayoffall goodbyesummer sadness bathingsuitsforever',
#  'untypical kinda friday dull',
#  'user fell heard snap hfhj',
#  'half past midnight loud banging front door told new rape case edinburgh today joyful nosleep',
#  '5am blue riding cab homen belly much bigger rest bodyn couldnt preggyn lose day',
#  'there always one song make turn radio youd rather sit silence',
#  'symmetry key everything must aesthetically pleasing possible hold twin pistol deaththekid bot',
#  'totally knew trump finally get revenge soninlaws prosecutionimprisonment throw christie bus',
#  'recording fnaf facetime mum let know okay let high pitched scream horror suchagirl',
#  'user like despite irritation towards ur ship least canon buckynat canon clintwanda canon',
#  'user user yeah figured ornament way wanted spektar desolate gear well thought right',
#  'panda eyed jaunty watching jaw late',
#  'contactless affliction kart need must regarding psychological moment xbeujgb',
#  'dont even feel anger anymore cant explain tulsa charlotte trayvon sandrabland philando ferguson batonrouge michaelbrown',
#  'projection perception see someone else also level within anger worry',
#  'people need way escapeescape whatthis corrupted worldthis reality jokethis fury constant pain amp stresswe need vacation',
#  'user amp user must rejoicing ovet charlotte protest nnorthcarolina',
#  'user fix homeaway deptch chart invalid glitch close madden reopen everytime happens',
#  'user think need white people vote wouldnt reach thing concern amp leave rest',
#  'bilal abood iraq immigrant life mesquite texas sentenced month prison lying fed terrorism',
#  'know going one night take act god fall asleep restless',
#  'banger sit reason great doings alias rejoice kzfqr',
#  'feel furious',
#  'dont know whats worse new pizza hut commercial pizza pizza hut make',
#  'always thought empathetic becoming clear majority guy plain insensitive alarming degree',
#  'nawazsharif say let end terror sure let indianarmedforces target base without pakistan interference karma',
#  'user user user entire team coach played coached scared jumpstreet intimidated',
#  'floofeli wonder mother know dark humor beneeds realize much butt apple pastel catscutie pie',
#  'doesnt anybody know watch penny dreadful',
#  'thank user balloon today smile goodday',
#  'currently listening user amp user user podcasts guy please move yvr hilarious missyou',
#  'depression suck',
#  'user hard tell pic mistake either way nothing said initially race u took ignorant',
#  'maybe parentsthat would understand fear indifference mom dad',
#  'user bubble implies burst',
#  'user user new campaign slogan ideai know trump yourefired deflect',
#  'school photo honestly horrid look ew',
#  'im mad injustice im going smash neighbour window make perfect sense charlotteprotest',
#  'user user grudge truth abundance',
#  'thats evening though way lit finish properly without causing serious mischief',
#  'user oh true true',
#  'user customer service beyond appalling faulty dryer replacement break within wks part wks engineer show',
#  'world nicole beat paul terrible bb18 bbfinale jury thinking',
#  'barish sad song prefect night feeling alone',
#  'walk right see way past dont even hesitate running',
#  'im really constipated depressing',
#  'user user individual clearly trying intimidate leo see issue stop causing issue pushing limit',
#  'autumnalequinox night drawing great time look putting new light dark showroom news wirral',
#  'isnt whole hijacked argument argument used ban discourage display st george cross shame user',
#  'watch amazing lively broadcast user musically',
#  'rocky horror remake look bit w n k',
#  'wish unlimited glee episode could watch forever gleegoodbye',
#  'user come glasgow night working fucking gutted waiting appearance age',
#  'absolutely fuming woman jumped prebooked taxi drove',
#  'user concerned pakistan internal affair terrorism state amp economic policyterroristnation',
#  'trump make america great plan exactly like first minute movie childrenofmencages terrorism refugee',
#  'im like better moment cuz panic later obviously better every opportunity choose make seem',
#  'user user good one reporter quit sad',
#  'user preordered pale ep would paid phone call would freaked said anything',
#  'paul forever paul paul played better game bb18 angry',
#  'never afraid start',
#  'miss fact burkeramsey swung amphit sister jonbenet face golf club previously fit anger',
#  'wont even get started hillary fancy fundraiser depressing',
#  'user forest gate u could see bully cunt big bald cunt mate looked shock hit didnt shit',
#  'indiamissingindira could never solve kashmir problem kept burning vote banknterrorstatepak',
#  'quote u fear control u fear life ur mind real difficulty overcome cheryl janecky',
#  'shake mouth chattering couldnt take right body trembling went outside',
#  'depressing seeing whole fam packing go holiday tomorrow im staying',
#  'schneiderlin taking revenge foul',
#  'lol little thing like make angry x',
#  'cuddling literally kill depression relief anxiety strengthens immune system',
#  'user user varsity pine riding',
#  'turned better expected admitting tried intimidate cantstoplaughing really cant spokeword',
#  'user oh good god quentin letts one comedy turn angry user user bbctw',
#  'user user dreadful franglaise',
#  'user doesnt explain ability land manchester bradford convenient flybe many unhappy traveler',
#  'watch amazing lively broadcast user musically',
#  'user may suggest meal made bean onion amp garlic day class',
#  'hate im singing idiot think join likethis fcking glee meanrikonabot',
#  'dentist said im going numb front lip itll feel youve got lip like pete burn right pout',
#  'people often grudge others cannot enjoy',
#  'yeah im hot nigga say im burning uh',
#  'want police state fearful imbecilesinterpretingall user user user',
#  'lmboo using nephew meme hilarious',
#  'user irate checkin system tried checkin day wouldnt let seat assigned',
#  'user event started everyone getting ready travel lake rage everything glow',
#  'user fear amp anger similar hitler preached come power germany wake america',
#  'srpt would etep patient amp mom advocate drug work anyone listen etep md adcomm elated',
#  'user ill vip ticket cant wait meet never met famous person admire nervous',
#  'user user fun funniest person funsville much hilarity usual thank',
#  'user social anxiety many awkward thing wrong',
#  'user user struggle real whoa worry younger generation',
#  'matt psychological study provocation abusive relationship',
#  'user user ya confident offense good yearsour suck',
#  'user give frustrated growl stepping closer putting gun barrier alarm nothing happened',
#  'thanks ripping luthansa enough one way flight man frk bag free gate',
#  'user please canadian player play u player lag atrocious fixthisgame trash sfvrefund',
#  'gahhbt queue minute put bt sport dept cancel back queue',
#  'user switch host bullet rage',
#  'monster monster view fear',
#  'user dont leave',
#  'user fucking hell mate absolute nightmare',
#  'michelle nothing hating nicoles game hahaha bitter bb18',
#  'stuck roof house provides amazing view sheer terror falling kinda like life',
#  'think val might going week ill take rest week work mourn im sure theyll understand gbbo',
#  'user appointment booked today waited day nobody showed also requested call back never got one',
#  'user user user user user user user user user insult',
#  'im gloomy today',
#  'user red one would look super pretty bronzy glowy nude lip makeup look 3rd black would pretty dark lip',
#  'user user usa embarrassing watch last time guy game joke',
#  'already tell programme going infuriate extremeworld',
#  'watch amazing lively broadcast user lively musically',
#  'week full monday end',
#  'checking work todaynncoffee drank serious business nnthursday bring friday',
#  'whats box search google chrome horrible distracting',
#  'last night dream today christmas woke screaming wasnt ready',
#  'minute incense get rattatas pokemongo',
#  'user ive disconnected whilst holiday dont move house 1st october',
#  'sound like donald trump spent today making extra extra sure hed get frightened white conservative racist vote',
#  'lost im faded',
#  'dont know expect brendons video lmao la devotee video got shook',
#  'anyone else find user anniversary window update complete nightmare',
#  'user cant believe rude cashier today returning item customer service slacking terrible',
#  'user user hilarious',
#  'friday open tonight tomorrow get jump halloween come play u hauntedattraction tulsa haunt',
#  'user give gleeful squeak wrap around mine',
#  'moving clip youtube tonight vigil held tulsa metropolitan baptist church terencecruther justice sadness',
#  'watched tna first time long time hell happened hardyboys impactonpop wwe terrible',
#  'man know juggle didnt ball itn funny pun lol punny',
#  'user whats 50p minute charge insult injury',
#  'unruly kid 8am morning nothanks ripping flower bed root parent watch shocking',
#  'user user yep pointed politics loathing thats big candidate horrible',
#  'user user hi dom saw u notts county away looking mufc away ticket pay blue',
#  'spend shimmy drink ill raging know gonna happen',
#  'look like india finally taking pakistan n terrorism taskuriattacks',
#  'user old age hope rest u destined become deatheaters',
#  'rojo terrible team',
#  'ah little user soothe soul music blue',
#  'whole idea f nation revolves around kashmir amp global terrorism evrn dont care kid dying hunger nawazfightsforkashmir',
#  'need advice get rut depressing needmotivation',
#  'blame whole season natalie season would different turned back alliance pissed bitter',
#  'user look way let think rohan last week optimism',
#  'thinking trying comedy youtube always fond time nut laughter comedy maybeoneday hopefullyfunny lol',
#  'dont think fully sunk val gone yet',
#  'user lol love aggravate juan keep good work lol',
#  'user user wat irony pakistan lecturing world curbing',
#  'user cheer chuck',
#  'shoutout drunk man bus pissed bottle seat',
#  'user goodbye despair',
#  'headed mdw w layover slc got food wrong move bailed food amp barely made user wannagetaway contest',
#  'someone wake user make remix whybw terrencecrutcher election colinkapernick terrorism riot 2much',
#  'unbelievable take minute get user there fault call hang fuming treatcustomersfairly',
#  'manchester derby home revenge',
#  'user lt change follows behind scowl pinching lip take sheet room gt',
#  'ghost id haunt people giving cramp leg cardio mwahaha',
#  'sure ohio state terrible ohio awful etc etcnnthese feeling began toldeo war nnso maybe dont campaign',
#  'user see primary care doctor prescribe med refer psychiatrist eval dont mess depression',
#  'obama admin reject texas plan refugee vetted terrorism texas pull fed refugee resettlement program aiding',
#  'gbbo homely pure piece tv gold channel attempt tart mary sue mel gone im fuming',
#  'gifs io messaging app hilarious',
#  'user stopped smiled rudenot funnyit mean stoppickingonwomen',
#  'user dobetter two carriage birmingham hereford room stand anymore friday commute unhappy',
#  'hi berniebrocialists gender lived swingish state would wo hesitation vote clinton amp would wo supporting',
#  'asked jared marry said',
#  'im want see dick snapkik hiya kik kikme snapchat snapme horny porn naked young',
#  'texan played horrible bad play calling bad protection ball bad coaching bad defense bad overall performance texan horrible',
#  'user sadly enough name whole farewell tour situation would make shy away good value b et',
#  'bayern munich pitch horrific',
#  'least dont guy trying discourage anymore want never become anything worth contributing society',
#  'user awe thank much lyle youre best',
#  'user user user pledge would never made petulant child postrump didnt threaten run',
#  'user hard tell pic mistake either way nothing said initially race u took sad ignorant',
#  'try find good negative negative turn goodnanxietyrelief optimism openminded',
#  'would enrique sub busquet hilarious',
#  'rapper stayed true game rich',
#  'ughh want like nightmare get along',
#  'user good greatdont breathe horror film month fav horror film year far',
#  'resent biting tongue',
#  'busy coding whole network manager unity 3d based steamworks networking gamedev indiedev 3amdeadtime game',
#  'let general tweet offend definitely shouldnt twitter',
#  'ever really lonely phone keep blowing cant pick respond people anxiety recluse issue',
#  'instagram seriously sort sht spent age writing caption delete post fume instagram',
#  'user charge extra sending someone cable service still doesnt work thats robbery cable horrible service',
#  'regret thing tempered time regret thing inconsolable sydney j harris',
#  'user worry emphasis keeping family together guiding principle due experience',
#  'user klitschko user fury day boxing',
#  'thats fucking horrific defending schalke',
#  'feel like one twitter anyone see write sadness rant',
#  'lol mention pak pm even speech international news channel pakis rejoicing world stand',
#  'user directtv best apparently sit silent anger dont press say anything',
#  'ok fast amp furious movie classified comedy',
#  'user terrible paul deserved win bbfail',
#  'playing antichrist wont user play hustle outrage',
#  'user charlotteprotest u wait fact video u hate ask question later protest policeshootings suggestion',
#  ...]
